# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
# plt.show()  -- Run this when you are using MatPlotLib outside of Jupyter notebooks

# %%
import numpy as np
x = np.linspace(0,5,11)
y = x ** 2

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
# Functional method to create a basic plot 
plt.plot(x,y)
plt.xlabel('X Label')
plt.ylabel('Y Label')
plt.title('Title')
# Out:
# Text(0.5, 1.0, 'Title')

# %% [markdown]
# ### Putting multi-plots on the same canvas

# %%
plt.subplot(1,2,1) #Row, Columns, # plot you are reffering to
plt.plot(x,y,'r') # Color Red 'r'

plt.subplot(1,2,2)
plt.plot(y,x,'b')

# %% [markdown]
# ### Object oriented method

# %%
fig = plt.figure()

axes = fig.add_axes([0.1,0.1,0.8,0.8]) # Left, Bottom, Width and Height

axes.plot(x,y)
axes.set_xlabel('X Label')
axes.set_ylabel('Y Label')
axes.set_title('Title')
# Out:
# Text(0.5, 1.0, 'Title')

# %%
fig = plt.figure()

axes1 = fig.add_axes([0.1,0.1,0.8,0.8]) # These are percent between 0-1
axes2 = fig.add_axes([0.2,0.5,0.4,0.3]) # Left, Bottom, Width and Height

axes1.plot(x,y)
axes1.set_title('Larger Plot')

axes2.plot(y,x)
axes2.set_title('Smaller Plot')
# Out:
# Text(0.5, 1.0, 'Smaller Plot')

# %%
fig,axes = plt.subplots(nrows=1,ncols=3) # Tuple unpacking

for current_ax in axes:
    current_ax.plot(x,y)

# %%
# since we set axes = plt.subplots axes is really just a list now, and we can treat it like a list by indexing 
fig,axes = plt.subplots(nrows=1,ncols=3)

axes[0].plot(x,y)
axes[0].set_title('First Plot')

axes[1].plot(y,y)
axes[1].set_title('Second Plot')

plt.tight_layout() # Fix the overlap

# %% [markdown]
# ### Figure Size and DPI

# %%
fig = plt.figure(figsize=(8,2))

ax = fig.add_axes([0,0,1,1,])
ax.plot(x,y)

# %%
fig,axes = plt.subplots(nrows=2, ncols=1, figsize=(8,2), dpi=100)

axes[0].plot(x,y)
axes[1].plot(y,y)

plt.tight_layout()

# %% [markdown]
# ### Save a figure to a file

# %%
fig.savefig('my_testfig.png', dpi=200)

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1,])
ax.plot(x,x **2, label='X Squared')
ax.plot(x,x ** 3, label='X Cubed')
ax.plot(x,x, label='X')

ax.legend(loc=0)

ax.set_title('Title')
ax.set_ylabel('YLabel')
ax.set_xlabel('XLabel')

plt.xlim([0, max(x) + 1])
plt.ylim([0, max(y) + 1])
# Out:
# (0.0, 26.0)

# %% [markdown]
# ### Plot appearance

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y, 
        color='#FF8C00', # RGB hexcodes
        linewidth=2, # lw for short
        alpha=0.5, # Transparency
        linestyle='-.', # There are lots of these styles, and you can use ls for short
        marker = '*', 
        markersize = 20,
        markerfacecolor = 'blue',
        markeredgewidth = 3,
        markeredgecolor = 'green'
       ) 

plt.xlim([0, max(x) + 1])
plt.ylim([0, max(y) + 1])
# Out:
# (0.0, 26.0)

# %% [markdown]
# ### Control over axis appearance

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y, 
        color='#FF8C00', # RGB hexcodes
        linewidth=2, # lw for short
        alpha=0.5, # Transparency
        linestyle='-.', # There are lots of these styles, and you can use ls for short
        marker = '*', 
        markersize = 20,
        markerfacecolor = 'blue',
        markeredgewidth = 3,
        markeredgecolor = 'green'
       ) 

ax.set_xlim([0,1])  
ax.set_ylim([0,2])
# Out:
# (0.0, 2.0)

# %% [markdown]
# ### Specialized plot types

# %% [markdown]
# #### Scatter Plot

# %%
plt.scatter(x,y)

# %% [markdown]
# #### Histogram

# %%
from random import sample
data = sample(range(1,1000), 100)

plt.hist(data)
# Out:
# (array([17.,  8.,  9., 10.,  7.,  7.,  5., 10., 14., 13.]),
#  array([  7. , 106.2, 205.4, 304.6, 403.8, 503. , 602.2, 701.4, 800.6,
#         899.8, 999. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# #### Boxplots

# %%
data = [np.random.normal(0,std,100) for std in range(1,4)]

# rectangular box plot
plt.boxplot(data,vert=True, patch_artist=True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2c8bd8bfaf0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2c8bd8d10d0>,
# ...
#  'boxes': [<matplotlib.patches.PathPatch at 0x2c8bd8bf730>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x2c8bd8d1670>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x2c8bd8d1940>,
# ...
#  'means': []}
